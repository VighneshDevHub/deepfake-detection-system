# %% [markdown]
# ### Mount Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
os.makedirs("/content/drive/MyDrive/deepfake_project/checkpoints", exist_ok=True)
os.makedirs("/content/drive/MyDrive/deepfake_project/exports",     exist_ok=True)

print("Drive mounted.")
print("Folders ready.")
